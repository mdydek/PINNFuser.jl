# %%
using JLD2
using OrdinaryDiffEq, Lux, StableRNGs, ComponentArrays
using DelimitedFiles

@load "models/PINN_sol.jld2" PINN_sol
# Out:
# ┌ Warning: type OptimizationBase.#grad#16{SciMLBase.NullParameters,OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},Main.#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},AutoForwardDiff{nothing, Nothing}} does not exist in workspace; reconstructing
# └ @ JLD2 /Users/michal/.julia/packages/JLD2/pdSa4/src/data/reconstructing_datatypes.jl:574
# ┌ Warning: type OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},Main.#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing} does not exist in workspace; reconstructing
# └ @ JLD2 /Users/michal/.julia/packages/JLD2/pdSa4/src/data/reconstructing_datatypes.jl:458
# ┌ Warning: type OptimizationBase.#fg!#18{SciMLBase.NullParameters,OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},Main.#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},AutoForwardDiff{nothing, Nothing}} does not exist in workspace; reconstructing
# └ @ JLD2 /Users/michal/.julia/packages/JLD2/pdSa4/src/data/reconstructing_datatypes.jl:574
# ┌ Warning: some parameters could not be resolved for type OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},Main.#3#4,JLD2.ReconstructedMutable{Symbol("#grad#16{SciMLBase.NullParameters,OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},AutoForwardDiff{nothing, Nothing}}"), (:p, :f, :adtype, :prep_grad), Tuple{SciMLBase.NullParameters, JLD2.ReconstructedSingleton{Symbol("OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}")}, AutoForwardDiff{nothing, Nothing}, Any}},JLD2.ReconstructedMutable{Symbol("#fg!#18{SciMLBase.NullParameters,OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},AutoForwardDiff{nothing, Nothing}}"), (:p, :f, :adtype, :prep_grad), Tuple{SciMLBase.NullParameters, JLD2.ReconstructedSingleton{Symbol("OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}")}, AutoForwardDiff{nothing, Nothing}, Any}},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}; reconstructing
# └ @ JLD2 /Users/michal/.julia/packages/JLD2/pdSa4/src/data/reconstructing_datatypes.jl:570
# ┌ Warning: type Main.#3#4 does not exist in workspace; reconstructing
# └ @ JLD2 /Users/michal/.julia/packages/JLD2/pdSa4/src/data/reconstructing_datatypes.jl:458
# ┌ Warning: type OptimizationBase.OptimizationCache{JLD2.ReconstructedStatic{Symbol("OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,JLD2.ReconstructedMutable{Symbol(\"#grad#16{SciMLBase.NullParameters,OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},AutoForwardDiff{nothing, Nothing}}\"), (:p, :f, :adtype, :prep_grad), Tuple{SciMLBase.NullParameters, JLD2.ReconstructedSingleton{Symbol(\"OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}\")}, AutoForwardDiff{nothing, Nothing}, Any}},JLD2.ReconstructedMutable{Symbol(\"#fg!#18{SciMLBase.NullParameters,OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},AutoForwardDiff{nothing, Nothing}}\"), (:p, :f, :adtype, :prep_grad), Tuple{SciMLBase.NullParameters, JLD2.ReconstructedSingleton{Symbol(\"OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}\")}, AutoForwardDiff{nothing, Nothing}, Any}},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}"), (:f, :adtype, :grad, :fg, :hess, :fgh, :hv, :cons, :cons_j, :cons_jvp, :cons_vjp, :cons_h, :hess_prototype, :cons_jac_prototype, :cons_hess_prototype, :observed, :expr, :cons_expr, :sys, :lag_h, :lag_hess_prototype, :hess_colorvec, :cons_jac_colorvec, :cons_hess_colorvec, :lag_hess_colorvec, :initialization_data), Tuple{JLD2.ReconstructedSingleton{Symbol("#3#4")}, AutoForwardDiff{nothing, Nothing}, JLD2.ReconstructedMutable{Symbol("#grad#16{SciMLBase.NullParameters,OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},AutoForwardDiff{nothing, Nothing}}"), (:p, :f, :adtype, :prep_grad), Tuple{SciMLBase.NullParameters, JLD2.ReconstructedSingleton{Symbol("OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}")}, AutoForwardDiff{nothing, Nothing}, Any}}, JLD2.ReconstructedMutable{Symbol("#fg!#18{SciMLBase.NullParameters,OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},AutoForwardDiff{nothing, Nothing}}"), (:p, :f, :adtype, :prep_grad), Tuple{SciMLBase.NullParameters, JLD2.ReconstructedSingleton{Symbol("OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,N ...
# └ @ JLD2 /Users/michal/.julia/packages/JLD2/pdSa4/src/data/reconstructing_datatypes.jl:574
# ┌ Warning: type Main.#1#2 does not exist in workspace; reconstructing
# └ @ JLD2 /Users/michal/.julia/packages/JLD2/pdSa4/src/data/reconstructing_datatypes.jl:458
# ┌ Warning: type parameters for SciMLBase.OptimizationSolution{Float64,1,ComponentVector{Float64, Vector{Float64}, Tuple{Axis{(layer_1 = ViewAxis(1:80, Axis(weight = ViewAxis(1:70, ShapedAxis((10, 7))), bias = ViewAxis(71:80, Shaped1DAxis((10,))))), layer_2 = ViewAxis(81:190, Axis(weight = ViewAxis(1:100, ShapedAxis((10, 10))), bias = ViewAxis(101:110, Shaped1DAxis((10,))))), layer_3 = ViewAxis(191:300, Axis(weight = ViewAxis(1:100, ShapedAxis((10, 10))), bias = ViewAxis(101:110, Shaped1DAxis((10,))))), layer_4 = ViewAxis(301:377, Axis(weight = ViewAxis(1:70, ShapedAxis((7, 10))), bias = ViewAxis(71:77, Shaped1DAxis((7,))))))}}},JLD2.ReconstructedMutable{Symbol("OptimizationCache{JLD2.ReconstructedStatic{Symbol(\"OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,JLD2.ReconstructedMutable{Symbol(\\\"#grad#16{SciMLBase.NullParameters,OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},AutoForwardDiff{nothing, Nothing}}\\\"), (:p, :f, :adtype, :prep_grad), Tuple{SciMLBase.NullParameters, JLD2.ReconstructedSingleton{Symbol(\\\"OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}\\\")}, AutoForwardDiff{nothing, Nothing}, Any}},JLD2.ReconstructedMutable{Symbol(\\\"#fg!#18{SciMLBase.NullParameters,OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},AutoForwardDiff{nothing, Nothing}}\\\"), (:p, :f, :adtype, :prep_grad), Tuple{SciMLBase.NullParameters, JLD2.ReconstructedSingleton{Symbol(\\\"OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}\\\")}, AutoForwardDiff{nothing, Nothing}, Any}},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}\"), (:f, :adtype, :grad, :fg, :hess, :fgh, :hv, :cons, :cons_j, :cons_jvp, :cons_vjp, :cons_h, :hess_prototype, :cons_jac_prototype, :cons_hess_prototype, :observed, :expr, :cons_expr, :sys, :lag_h, :lag_hess_prototype, :hess_colorvec, :cons_jac_colorvec, :cons_hess_colorvec, :lag_hess_colorvec, :initialization_data), Tuple{JLD2.ReconstructedSingleton{Symbol(\"#3#4\")}, AutoForwardDiff{nothing, Nothing}, JLD2.ReconstructedMutable{Symbol(\"#grad#16{SciMLBase.NullParameters,OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},AutoForwardDiff{nothing, Nothing}}\"), (:p, :f, :adtype, :prep_grad), Tuple{SciMLBase.NullParameters, JLD2.ReconstructedSingleton{Symbol(\"OptimizationFunction{true,AutoForwardDiff{nothing, Nothing},#3#4,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME),Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}\")}, AutoForwardDiff{nothing, Nothing}, Any}}, JLD2.ReconstructedMutable{Symbol(\"#fg!#18{SciMLBase.Null ...
# └ @ JLD2 /Users/michal/.julia/packages/JLD2/pdSa4/src/data/reconstructing_datatypes.jl:560
# ┌ Warning: some parameters could not be resolved for type ForwardDiff.Dual{ForwardDiff.Tag{Main.#3#4,Float64},Float64,12}; reading as ForwardDiff.Dual{Any, Float64, 12}
# └ @ JLD2 /Users/michal/.julia/packages/JLD2/pdSa4/src/data/reconstructing_datatypes.jl:566
# ┌ Warning: some parameters could not be resolved for type DifferentiationInterfaceForwardDiffExt.ForwardDiffGradientPrep{Nothing,ForwardDiff.GradientConfig{ForwardDiff.Tag{Main.#3#4,Float64},Float64,12,ComponentVector{ForwardDiff.Dual{Any, Float64, 12}, Vector{ForwardDiff.Dual{Any, Float64, 12}}, Tuple{Axis{(layer_1 = ViewAxis(1:80, Axis(weight = ViewAxis(1:70, ShapedAxis((10, 7))), bias = ViewAxis(71:80, Shaped1DAxis((10,))))), layer_2 = ViewAxis(81:190, Axis(weight = ViewAxis(1:100, ShapedAxis((10, 10))), bias = ViewAxis(101:110, Shaped1DAxis((10,))))), layer_3 = ViewAxis(191:300, Axis(weight = ViewAxis(1:100, ShapedAxis((10, 10))), bias = ViewAxis(101:110, Shaped1DAxis((10,))))), layer_4 = ViewAxis(301:377, Axis(weight = ViewAxis(1:70, ShapedAxis((7, 10))), bias = ViewAxis(71:77, Shaped1DAxis((7,))))))}}}},Tuple{Nothing}}; reading as DifferentiationInterfaceForwardDiffExt.ForwardDiffGradientPrep{Nothing, Any, Tuple{Nothing}}
# └ @ JLD2 /Users/michal/.julia/packages/JLD2/pdSa4/src/data/reconstructing_datatypes.jl:566
# ┌ Warning: some parameters could not be resolved for type ForwardDiff.GradientConfig{ForwardDiff.Tag{Main.#3#4,Float64},Float64,12,ComponentVector{ForwardDiff.Dual{Any, Float64, 12}, Vector{ForwardDiff.Dual{Any, Float64, 12}}, Tuple{Axis{(layer_1 = ViewAxis(1:80, Axis(weight = ViewAxis(1:70, ShapedAxis((10, 7))), bias = ViewAxis(71:80, Shaped1DAxis((10,))))), layer_2 = ViewAxis(81:190, Axis(weight = ViewAxis(1:100, ShapedAxis((10, 10))), bias = ViewAxis(101:110, Shaped1DAxis((10,))))), layer_3 = ViewAxis(191:300, Axis(weight = ViewAxis(1:100, ShapedAxis((10, 10))), bias = ViewAxis(101:110, Shaped1DAxis((10,))))), layer_4 = ViewAxis(301:377, Axis(weight = ViewAxis(1:70, ShapedAxis((7, 10))), bias = ViewAxis(71:77, Shaped1DAxis((7,))))))}}}}; reading as ForwardDiff.GradientConfig{Any, Float64, 12, ComponentVector{ForwardDiff.Dual{Any, Float64, 12}, Vector{ForwardDiff.Dual{Any, Float64, 12}}, Tuple{Axis{(layer_1 = ViewAxis(1:80, Axis(weight = ViewAxis(1:70, ShapedAxis((10, 7))), bias = ViewAxis(71:80, Shaped1DAxis((10,))))), layer_2 = ViewAxis(81:190, Axis(weight = ViewAxis(1:100, ShapedAxis((10, 10))), bias = ViewAxis(101:110, Shaped1DAxis((10,))))), layer_3 = ViewAxis(191:300, Axis(weight = ViewAxis(1:100, ShapedAxis((10, 10))), bias = ViewAxis(101:110, Shaped1DAxis((10,))))), layer_4 = ViewAxis(301:377, Axis(weight = ViewAxis(1:70, ShapedAxis((7, 10))), bias = ViewAxis(71:77, Shaped1DAxis((7,))))))}}}}
# └ @ JLD2 /Users/michal/.julia/packages/JLD2/pdSa4/src/data/reconstructing_datatypes.jl:566
# ┌ Warning: type OptimizationBase.ReInitCache{ComponentVector{Float64, Vector{Float64}, Tuple{Axis{(layer_1 = ViewAxis(1:80, Axis(weight = ViewAxis(1:70, ShapedAxis((10, 7))), bias = ViewAxis(71:80, Shaped1DAxis((10,))))), layer_2 = ViewAxis(81:190, Axis(weight = ViewAxis(1:100, ShapedAxis((10, 10))), bias = ViewAxis(101:110, Shaped1DAxis((10,))))), layer_3 = ViewAxis(191:300, Axis(weight = ViewAxis(1:100, ShapedAxis((10, 10))), bias = ViewAxis(101:110, Shaped1DAxis((10,))))), layer_4 = ViewAxis(301:377, Axis(weight = ViewAxis(1:70, ShapedAxis((7, 10))), bias = ViewAxis(71:77, Shaped1DAxis((7,))))))}}},SciMLBase.NullParameters} does not exist in workspace; reconstructing
# └ @ JLD2 /Users/michal/.julia/packages/JLD2/pdSa4/src/data/reconstructing_datatypes.jl:574
# ┌ Warning: type OptimizationBase.AnalysisResults{Nothing,Nothing} does not exist in workspace; reconstructing
# └ @ JLD2 /Users/michal/.julia/packages/JLD2/pdSa4/src/data/reconstructing_datatypes.jl:458
# 1-element Vector{Symbol}:
#  :PINN_sol

# %%
function Valve(R, deltaP, open)
    dq = 0.0
    if (-open) < 0.0
        dq = deltaP / R
    else
        dq = 0.0
    end
    return dq

end

function ShiElastance(t, Eₘᵢₙ, Eₘₐₓ, τ, τₑₛ, τₑₚ, Eshift)
    τₑₛ = τₑₛ * τ

    τₑₚ = τₑₚ * τ
    #τ = 4/3(τₑₛ+τₑₚ)
    tᵢ = rem(t + (1 - Eshift) * τ, τ)

    Eₚ =
        (tᵢ <= τₑₛ) * (1 - cos(tᵢ / τₑₛ * pi)) / 2 +
        (tᵢ > τₑₛ) * (tᵢ <= τₑₚ) * (1 + cos((tᵢ - τₑₛ) / (τₑₚ - τₑₛ) * pi)) / 2 +
        (tᵢ <= τₑₚ) * 0

    E = Eₘᵢₙ + (Eₘₐₓ - Eₘᵢₙ) * Eₚ

    return E
end

function DShiElastance(t, Eₘᵢₙ, Eₘₐₓ, τ, τₑₛ, τₑₚ, Eshift)

    τₑₛ = τₑₛ * τ
    τₑₚ = τₑₚ * τ
    #τ = 4/3(τₑₛ+τₑₚ)
    tᵢ = rem(t + (1 - Eshift) * τ, τ)

    DEₚ =
        (tᵢ <= τₑₛ) * pi / τₑₛ * sin(tᵢ / τₑₛ * pi) / 2 +
        (tᵢ > τₑₛ) * (tᵢ <= τₑₚ) * pi / (τₑₚ - τₑₛ) * sin((τₑₛ - tᵢ) / (τₑₚ - τₑₛ) * pi) / 2
    (tᵢ <= τₑₚ) * 0
    DE = (Eₘₐₓ - Eₘᵢₙ) * DEₚ

    return DE
end


#Shi timing parameters
Eshift = 0.0
Eₘᵢₙ = 0.03

τₑₛ = 0.3
τₑₚ = 0.45
Eₘₐₓ = 1.5
Rmv = 0.006
τ = 1.0


function NIK_PINN!(du, u, p, t)
    pLV, psa, psv, Vlv, Qav, Qmv, Qs = u
    τₑₛ, τₑₚ, Rmv, Zao, Rs, Csa, Csv, Eₘₐₓ, Eₘᵢₙ = params

    # Neural Network component (NN for correction)
    NN_output = NN(u, p, st)[1]

    # The differential equations with NN correction
    du[1] =
        (Qmv - Qav) * ShiElastance(t, Eₘᵢₙ, Eₘₐₓ, τ, τₑₛ, τₑₚ, Eshift) +
        pLV / ShiElastance(t, Eₘᵢₙ, Eₘₐₓ, τ, τₑₛ, τₑₚ, Eshift) *
        DShiElastance(t, Eₘᵢₙ, Eₘₐₓ, τ, τₑₛ, τₑₚ, Eshift) +
        NN_output[1]
    du[2] = (Qav - Qs) / Csa + NN_output[2] #Systemic arteries     
    du[3] = (Qs - Qmv) / Csv + NN_output[3] # Venous
    du[4] = Qmv - Qav + NN_output[4] # LV volume
    du[5] = Valve(Zao, (du[1] - du[2]), u[1] - u[2]) + NN_output[5]  # AV 
    du[6] = Valve(Rmv, (du[3] - du[1]), u[3] - u[1]) + NN_output[6]  # MV
    du[7] = (du[2] - du[3]) / Rs + NN_output[7] # Systemic flow

end

u0 = [6.0, 6.0, 6.0, 200.0, 0.0, 0.0, 0.0]
params = [0.3, 0.45, 0.006, 0.033, 1.11, 1.13, 11.0, 1.5, 0.03]

NN = Lux.Chain(
    Lux.Dense(7, 10, elu),
    Lux.Dense(10, 10, elu),
    Lux.Dense(10, 10, elu),
    Lux.Dense(10, 7),
)

rng = StableRNG(5958)
p, st = Lux.setup(rng, NN)
p = 0.5 * ComponentVector{Float64}(p)
# Out:
# ComponentVector{Float64}(layer_1 = (weight = [-0.025089571252465248 -0.13317450881004333 … -0.12778112292289734 0.22667565941810608; 0.16364116966724396 -0.20269614458084106 … -0.05486127734184265 0.1415461152791977; … ; -0.1762702912092209 0.006427908316254616 … -0.12591703236103058 0.14767184853553772; -0.13822905719280243 -0.24787046015262604 … -0.18120597302913666 0.20931868255138397], bias = [-0.15276210010051727, 0.14352291822433472, 0.07330312579870224, -0.007145705167204142, 0.08284787833690643, 0.12516358494758606, -0.18695995211601257, 0.06358467042446136, -0.1222396194934845, 0.05672786757349968]), layer_2 = (weight = [-0.07584447413682938 -0.2616642117500305 … -0.16171568632125854 0.005802055820822716; 0.09017910063266754 -0.24110998213291168 … -0.13088202476501465 -0.011641394346952438; … ; -0.035823144018650055 0.21726873517036438 … 0.08900126814842224 0.1112726554274559; -0.05435895547270775 0.27346813678741455 … -0.06243923678994179 -0.11225976794958115], bias = [-0.04517688229680061, 0.13999640941619873, 0.051917873322963715, -0.06863141804933548, 0.10861074924468994, 0.03128200024366379, 0.13394588232040405, 0.08667220920324326, 0.13452035188674927, -0.09056626260280609]), layer_3 = (weight = [-0.21481820940971375 0.18619772791862488 … 0.16493375599384308 0.006263616029173136; -0.06650905311107635 -0.00922076404094696 … -0.014415066689252853 0.02628159336745739; … ; -0.12435462325811386 -0.013962908647954464 … -0.27012771368026733 0.1762535125017166; 0.14451350271701813 -0.2624680995941162 … 0.25191110372543335 0.07620704919099808], bias = [-0.045548953115940094, -0.11238013952970505, -0.14657779037952423, 0.11071127653121948, 0.11519374698400497, 0.13391618430614471, 0.1542566567659378, -0.05205158516764641, -0.018185095861554146, -0.12335702031850815]), layer_4 = (weight = [-0.2025550901889801 0.011452238075435162 … 0.15067505836486816 0.07748817652463913; 0.11860081553459167 0.12424042075872421 … 0.24196049571037292 0.010143558494746685; … ; -0.036841921508312225 -0.23529650270938873 … -0.06877010315656662 -0.14583367109298706; -0.25401148200035095 -0.13869604468345642 … 0.03924426808953285 0.2455943524837494], bias = [-0.124435655772686, 0.08502759039402008, -0.0672309622168541, 0.12951578199863434, -0.1328761875629425, -0.0874955952167511, 0.017955858260393143]))

# %%
tspan2 = (0.0, 20.0)
num_of_samples = 3000
tsteps = range(0.0, 20.0, length = num_of_samples)

trained_NN = ODEProblem(NIK_PINN!, u0, tspan2, PINN_sol.u)
s = solve(trained_NN, Vern7(), dtmax = 1e-2, saveat = tsteps, reltol = 1e-7, abstol = 1e-4)

data_to_save = hcat(s[1, :], s[2, :], s[3, :], s[4, :], s[5, :], s[6, :], s[7, :])

println("Pinn extrapolation saved to presaved_pinn_extrapolation.txt")
writedlm("data/presaved_pinn_extrapolation.txt", data_to_save)
# Out:
# Pinn extrapolation saved to presaved_pinn_extrapolation.txt
